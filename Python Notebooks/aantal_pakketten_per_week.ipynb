# %%
import matplotlib.pyplot as plt
import pandas as pd
# Read CSV file
df = pd.read_csv('/datc/parcel/notebooks/data/postnl/20200904_sample.csv', index_col=0, parse_dates=[1])

# %%
# Manipulate data
df['week'] = df['procesdag'].dt.isocalendar().week
new_df = df.groupby([df['cust_id'], df['week']]).agg(
    totaal_aantal_pakketten = ('aantal_pakketten', 'sum'),
    totaal_aantal_pakketten_volgende_dag = ('aantal_pakketten_volgende_dag', 'sum')
).reset_index()

# %%
# Define X and Y, 1st plot (klant 1)
df_klant1 = new_df.where(new_df['cust_id'] == 'klant_1').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant1['week'], df_klant1['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'week',
    ylabel = 'Aantal pakketten',
    title = 'Aantal pakketten per week voor klant 1')
plt.show()

# %%
# Define X and Y, 1st plot (klant 2)
df_klant1 = new_df.where(new_df['cust_id'] == 'klant_2').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant1['week'], df_klant1['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'week',
    ylabel = 'Aantal pakketten',
    title = 'Aantal pakketten per week voor klant 2')
plt.show()

# %%
# Define X and Y, 1st plot (klant 3)
df_klant1 = new_df.where(new_df['cust_id'] == 'klant_3').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant1['week'], df_klant1['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'week',
    ylabel = 'Aantal pakketten',
    title = 'Aantal pakketten per week voor klant 3')
plt.show()

# %%
# Define X and Y, 1st plot (klant 4)
df_klant1 = new_df.where(new_df['cust_id'] == 'klant_4').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant1['week'], df_klant1['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'week',
    ylabel = 'Aantal pakketten',
    title = 'Aantal pakketten per week voor klant 4')
plt.show()

# %%
# Define X and Y, 1st plot (klant 5)
df_klant1 = new_df.where(new_df['cust_id'] == 'klant_5').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant1['week'], df_klant1['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'week',
    ylabel = 'Aantal pakketten',
    title = 'Aantal pakketten per week voor klant 5')
plt.show()

# %%
# Define X and Y, 1st plot (klant 6)
df_klant1 = new_df.where(new_df['cust_id'] == 'klant_6').dropna()
fig, ax = plt.subplots()
ax.bar(df_klant1['week'], df_klant1['totaal_aantal_pakketten'])
ax.set(
    xlabel = 'week',
    ylabel = 'Aantal pakketten',
    title = 'Aantal pakketten per week voor klant 6')
plt.show()
